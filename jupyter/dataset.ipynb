# %%
import sys
sys.path.append('../src/utils')

# %%
from pathlib import Path
base_path = Path("/data1/ujiie/shinra/tohoku_bert/")

# %%
import json

for path in base_path.glob("**/"):
    if path.stem in ["tohoku_bert", "_temp_files", "tokens"]:
        continue
    if path.parent.stem == "tohoku_bert":
        continue

    if not (path / "tokens").exists():
        continue

    category = path.stem

    diff_cnt = 0
    total = 0

    vocab = load_vocab(path / "vocab.txt")
    anns = load_annotation(path / f"{category}_dist.json")

    for token_file in path.glob("tokens/*.txt"):
        page_id = int(token_file.stem)
        if page_id not in anns:
            continue
        ann = anns[page_id]

        tokens, text_offsets = load_tokens(token_file, vocab)
        print(tokens)
        for a in ann:
            if "token_offset" not in a:
                continue
            total += 1
            start_line = int(a["token_offset"]["start"]["line_id"])
            start_offset = int(a["token_offset"]["start"]["offset"])

            end_line = int(a["token_offset"]["end"]["line_id"])
            end_offset = int(a["token_offset"]["end"]["offset"])

            diff_cnt += int(tokens[start_line][start_offset].startswith("##")
                or (end_offset < len(tokens[end_line]) 
                    and tokens[end_line][end_offset].startswith("##")))
            
        break
    break
    
    print(f"{category}: {diff_cnt}/{total}")

# %%
import pickle

attributes = {}
attribute_path = Path("/data1/ujiie/shinra/tohoku_bert/attributes")
for path in attribute_path.glob("*.txt"):
    category = path.stem
    with open(path, "r") as f:
        attributes[category] = [l for l in f.read().split("\n") if l != ""]

with open("/data1/ujiie/shinra/tohoku_bert/attributes.pickle", "wb") as f:
    pickle.dump(attributes, f)

# %%
from collections import defaultdict

def load_tokens(path, vocab):
    tokens = []
    text_offsets = []
    with open(path, "r") as f:
        for line in f:
            line = line.rstrip().split()
            line = [l.split(",") for l in line]
            tokens.append([vocab[int(l[0])] for l in line])
            text_offsets.append([[l[1], l[2]] for l in line])

    return tokens, text_offsets

def load_vocab(path):
    vocab = []
    with open(path, "r") as f:
        for line in f:
            line = line.rstrip()
            if not line:
                continue
            vocab.append(line)
    return vocab

def load_annotation(path):
    ann = defaultdict(list)
    with open(path, "r") as f:
        for line in f:
            line = line.rstrip()
            if not line:
                continue
            line = json.loads(line)
            line["page_id"] = int(line["page_id"])
            ann[line["page_id"]].append(line)
    return ann

def find_word_alignment(tokens):
    word_idxs = []
    for idx, token in enumerate(tokens):
        if not token.startswith("##"):
            word_idxs.append(idx)

    return word_idxs

# %%
from pathlib import Path
import pickle
import json
from tqdm import tqdm

def find_word_alignment(tokens):
    word_idxs = []
    sub2word = {}
    for idx, token in enumerate(tokens):
        if not token.startswith("##"):
            word_idxs.append(idx)
        sub2word[idx] = len(word_idxs) - 1

    return word_idxs, sub2word


class ShinraData(object):
    def __init__(self, tokenizer, attributes_path, params={}):
        self.tokenizer = tokenizer
        with open(attributes_path, "rb") as f:
            self.attributes = pickle.load(f)
        self.attr2idx = {}
        for key, value in self.attributes.items():
            self.attr2idx[key] = {word: idx for idx, word in enumerate(value)}

        self.page_id = None
        self.page_title = None
        self.category = None
        self.plain_text = None
        self.tokens = None
        self.word_alignments = None
        self.sub2word = None
        self.text_offsets = None
        self.nes = None

        for key, value in params.items():
            setattr(self, key, value)

    @classmethod
    def from_shinra2020_format(
        cls, 
        tokenizer=None,
        attributes_path=None,
        input_path=None):

        input_path = Path(input_path)
        category = input_path.stem

        anns = load_annotation(input_path / f"{category}_dist.json")
        vocab = load_vocab(input_path / "vocab.txt")

        docs = []
        for token_file in tqdm(input_path.glob("tokens/*.txt")):
            page_id = int(token_file.stem)
            tokens, text_offsets = load_tokens(token_file, vocab)

            # find title
            title = "".join([t[2:] if t.startswith("##") else t for t in tokens[4]])
            pos = title.find("-jawiki")
            title = title[:pos]

            # find word alignments = start positions of words
            word_alignments = [find_word_alignment(t) for t in tokens]
            sub2word = [w[1] for w in word_alignments]
            word_alignments = [w[0] for w in word_alignments]

            data = {
                "page_id": page_id, 
                "page_title": title,
                "category": category,
                "tokens": tokens,
                "text_offsets": text_offsets,
                "word_alignments": word_alignments,
                "sub2word": sub2word,
            }

            if page_id in anns:
                data["nes"] = anns[page_id]
            else:
                continue

            docs.append(cls(tokenizer, attributes_path, params=data))

        return docs

    @property
    def words(self):
        all_words = []
        for tokens, word_alignments in zip(self.tokens, self.word_alignments):
            words = []
            prev_idx = 0
            for idx in word_alignments[1:] + [-1]:
                inword_subwords = tokens[prev_idx:idx]
                inword_subwords = [s[2:] if s.startswith("##") else s for s in inword_subwords]
                words.append("".join(inword_subwords))
                prev_idx = idx
            all_words.append(words)
        return all_words

    @property
    def iob(self):
        """
        %%% IOB for ** only word-level iob2 tag **
        iobs = [sent, sent, ...]
        sent = [[Token1_attr1_iob, Token2_attr1_iob, ...], [Token1_attr2_iob, Token2_attr2_iob, ...], ...]

        {"O": 0, "B": 1, "I": 2}
        """
        iobs = [[["O" for _ in range(len(tokens))] for _ in range(len(self.attributes[self.category]))] for tokens in self.word_alignments]
        for ne in self.nes:
            start_line = int(ne["token_offset"]["start"]["line_id"])
            start_offset = int(ne["token_offset"]["start"]["offset"])

            end_line = int(ne["token_offset"]["end"]["line_id"])
            end_offset = int(ne["token_offset"]["end"]["offset"])

            if start_line != end_line:
                continue

            # 正解となるsubwordを含むwordまでタグ付
            attr_idx = self.attr2idx[self.category][ne["attribute"]]
            ne_start = self.sub2word[start_line][start_offset]
            ne_end = self.sub2word[end_line][end_offset]
            for idx in range(ne_start, ne_end):
                iobs[start_line][attr_idx][idx] = "B" if idx == ne_start else "I"

        return iobs

# %%
dataset = ShinraData.from_shinra2020_format(None, "/data1/ujiie/shinra/tohoku_bert/attributes.pickle", Path("/data1/ujiie/shinra/tohoku_bert/Event/Event_Other"))
# Out:
# 525it [00:10, 50.94it/s]

# %%
outputs = []
with open("event_other.iob", "w") as f:
    for tokens, iobs in zip(dataset[5].words, dataset[5].iob):
        output = []
        flatten_iobs = [["O" for j in range(len(iobs))] for i in range(len(tokens))]
        print(len(flatten_iobs), len(tokens), len(iobs))
        for attr_idx, iob in enumerate(iobs):
            for token_idx, tag in enumerate(iob):
                if tag != "O":
                    tag = tag + "-" + dataset[5].attributes[dataset[5].category][attr_idx]
                flatten_iobs[token_idx][attr_idx] = tag
        for token, iob in zip(tokens, flatten_iobs):
            iob = "\t".join(iob)
            output.append(f"{token}\t{iob}")
        print(output)
        outputs.append("\n".join(output))

    attributes = ["token"] + dataset[5].attributes[dataset[5].category]
    attributes = "\t".join(attributes)
    f.write(f"{attributes}\n")
    f.write("\n\n".join(outputs))
# Out:
# \tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '結論\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'で\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ある\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'と\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'し\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'て\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'いる\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 60 60 11
# ['なお\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '、\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '宮沢\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '説\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'によって\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'も\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '、\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'そもそも\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '主権\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'を\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '制約\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'する\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '原理\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'が\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ある\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'で\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'は\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ない\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'か\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'という\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '問題\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'は\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '残る\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '尾\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '高説\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'は\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '、\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'この\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '問題\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'に対する\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '回答\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'とも\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '評価\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'できる\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '。\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ')\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'が\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '、\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'この\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '問題\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'は\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '現在\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'で\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'は\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '少なくとも\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '主権\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '所在\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'に関する\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '問題\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'と\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'は\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '捉え\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'られ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'て\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'い\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ない\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 5 5 11
# ['文献\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '情報\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '[\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '編集\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 30 30 11
# ['「\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '「\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '国民\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '主権\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '」\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '論\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '検討\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '1\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ')」\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '渡辺\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '良\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '二\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '滋賀大学\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '経済\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '学会\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '滋賀大学\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '学術\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '情報\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'リポジトリ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '1975\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '-\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '11\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ')[\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '1\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '][\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '2\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 34 34 11
# ['(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '参考\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ')\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '司法\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '試験\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '旧\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '司法\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '試験\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ')\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '平成\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '20\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '年度\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '第\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '2\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '次\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '試験\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '・\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '短\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '答\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '式\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '試験\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '問題\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '第\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '6\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '問\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ')[\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '3\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '](\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '正答\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '[\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '4\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ']\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 5 5 11
# ['関連\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '項目\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '[\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '編集\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 2 2 11
# ['君主\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 2 2 11
# ['国家\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 2 2 11
# ['国民\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 3 3 11
# ['社会\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '契約\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 4 4 11
# ['国家\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '有\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '機体\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 3 3 11
# ['天皇\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '主体\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 3 3 11
# ['天皇\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '機関\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 2 2 11
# ['継承\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 3 3 11
# ['法\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 2 2 11
# ['自然\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 2 2 11
# ['慣習\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 1 1 11
# ['\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 35 35 11
# ['「\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'http\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '://\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'dl\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '-\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'pcc\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '31\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '/\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'a\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '-\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'sumida\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '/\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'wiki\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '2019\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '_\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '1\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '/\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'index\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '.\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'php\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '?\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'title\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '=\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '尾\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '高\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '・\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '宮沢\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '論争\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '&\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'oldid\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '=\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '50333013\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '」\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'から\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO']
# 127 127 11
# ['カテゴリ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ':\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '日本国\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '憲法\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '日本\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '論争\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '日本\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '法学\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '史\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '案内\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'メニュー\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'Page\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'actions\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ノート\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '編集\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '履歴\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '表示\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'Page\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'actions\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ノート\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'More\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ツール\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '個人\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '用\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ツール\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ログイン\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'し\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'て\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'い\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ませ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ん\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'トーク\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '投稿\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '記録\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'アカウント\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '作成\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ログイン\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '検索\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '案内\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'メインページコミュニティ・ポータル\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '最近\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '出来\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '事新しい\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '最近\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '更新\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'おまかせ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '表示\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '練習\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '用\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページアップロード\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ウィキメディア・コモンズ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ')\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ヘルプ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ヘルプ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '井戸端\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'お知らせ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'バグ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '報告\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'sitesupport\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ウィキペディア\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'に関する\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'お\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '問い合わせ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ツール\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'リンク\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '元\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '関連\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '更新\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '状況\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '特別\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '印刷\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '用\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'バージョン\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'この\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '版\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'へ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'の\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '固定\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'リンク\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '情報\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'この\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ページ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'を\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '引用\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '最終\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '更新\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '2014\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '年\tO\tO\tO\tO ...
# 156 156 11
# ['(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'window\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '.\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'RLQ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '=\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'window\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '.\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'RLQ\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '||[]).\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'push\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'function\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '(){\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'mw\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '.\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'config\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '.\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'set\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '({"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'wgPageParseReport\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'limitreport\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'cputime\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '0\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '.\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '021\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '","\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'walltime\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '0\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '.\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '022\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '","\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ppvisitednodes\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'value\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '8\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ',"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'limit\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '1000000\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '},"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'ppgeneratednodes\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'value\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '20\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ',"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'limit\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '1000000\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '},"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'postexpandincludesize\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'value\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '0\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ',"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'limit\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '2097152\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '},"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'templateargumentsize\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'value\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '0\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ',"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'limit\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '2097152\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '},"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'expansiondepth\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'value\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '2\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ',"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'limit\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '40\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '},"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'expensivefunctioncount\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":{"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'value\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '0\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', ',"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'limit\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '":\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '100\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '},"\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', 'unstrip\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO\tO', '-\tO\tO\tO\tO\tO\tO\t ...
